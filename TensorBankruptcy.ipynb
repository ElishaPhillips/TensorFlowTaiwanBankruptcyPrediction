# %%
import os 
import pandas as pd
import numpy as np


from sklearn.model_selection import train_test_split
from tensorflow.keras.models import Sequential, load_model


import tensorflow as tf
from tensorflow.keras.layers import Dense, Flatten, Conv2D
from tensorflow.keras import Model
from sklearn.metrics import accuracy_score

os.chdir('C:\\Users\\Elisha\\Documents\\Python\\Portfolio\\ML\Bankruptcy')

# %%
bankruptcy = pd.read_csv('data.csv')

bankruptcyi = bankruptcy.rename(columns={x:y for x,y in zip(bankruptcy.columns,range(0,len(bankruptcy.columns)))})

bankruptcyi.head()
# Out:
#    0         1         2         3         4         5         6         7   \
# 0   1  0.370594  0.424389  0.405750  0.601457  0.601457  0.998969  0.796887
# 1   1  0.464291  0.538214  0.516730  0.610235  0.610235  0.998946  0.797380
# 2   1  0.426071  0.499019  0.472295  0.601450  0.601364  0.998857  0.796403
# 3   1  0.399844  0.451265  0.457733  0.583541  0.583541  0.998700  0.796967
# 4   1  0.465022  0.538432  0.522298  0.598783  0.598783  0.998973  0.797366
#
#          8         9   ...        86        87        88        89        90  \
# 0  0.808809  0.302646  ...  0.716845  0.009219  0.622879  0.601453  0.827890
# 1  0.809301  0.303556  ...  0.795297  0.008323  0.623652  0.610237  0.839969
# 2  0.808388  0.302035  ...  0.774670  0.040003  0.623841  0.601449  0.836774
# 3  0.808966  0.303350  ...  0.739555  0.003252  0.622929  0.583538  0.834697
# 4  0.809304  0.303475  ...  0.795016  0.003878  0.623521  0.598782  0.839973
#
#          91        92        93  94        95
# ...

# %%
X = pd.get_dummies(bankruptcyi.drop(0, axis=1))
y = bankruptcyi[0]

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=.2)

# %%
model = Sequential()
model.add(Dense(units=64, activation='relu', input_dim=len(X_train.columns)))
model.add(Dense(units=128, activation='relu'))
model.add(Dense(units=1, activation='sigmoid'))

# %%
model.compile(loss='binary_crossentropy', optimizer='sgd', metrics='accuracy')

# %%
model.fit(X_train, y_train, epochs=500, batch_size=32)
# Out:
# Epoch 1/500
# 171/171 [==============================] - 0s 581us/step - loss: nan - accuracy: 0.9265
# Epoch 2/500
# 171/171 [==============================] - 0s 563us/step - loss: nan - accuracy: 0.9706
# Epoch 3/500
# 171/171 [==============================] - 0s 551us/step - loss: nan - accuracy: 0.9659
# Epoch 4/500
# 171/171 [==============================] - 0s 563us/step - loss: nan - accuracy: 0.9715
# Epoch 5/500
# 171/171 [==============================] - 0s 563us/step - loss: nan - accuracy: 0.9661
# Epoch 6/500
# 171/171 [==============================] - 0s 587us/step - loss: nan - accuracy: 0.9739
# Epoch 7/500
# 171/171 [==============================] - 0s 663us/step - loss: nan - accuracy: 0.9691
# Epoch 8/500
# 171/171 [==============================] - 0s 634us/step - loss: nan - accuracy: 0.9688
# Epoch 9/500
# 171/171 [==============================] - 0s 593us/step - loss: nan - accuracy: 0.9671
# Epoch 10/500
# ...

# %%
y_hat = model.predict(X)
y_hat = [1 if val < 0.5 else 0 for val in y_hat]

accuracy_score(y, y_hat)
# Out:
# 0.967737204868749
